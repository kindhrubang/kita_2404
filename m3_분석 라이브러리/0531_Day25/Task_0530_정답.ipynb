# %% [markdown]
# Task1_0530. 고객 정보 데이터프레임과 구매 내역 데이터프레임을 결합하여 각 고객이름(name) 별 총 지출을 계산하여 출력하세요.

# %%
import pandas as pd
import numpy as np
# 고객 정보 데이터프레임 생성
customers = pd.DataFrame({
    'customer_id': [1, 2, 3, 4],
    'name': ['Alice', 'Bob', 'Charlie', 'David']
})

# 구매 내역 데이터프레임 생성
purchases = pd.DataFrame({
    'purchase_id': [101, 102, 103, 104, 105],
    'customer_id': [1, 2, 1, 3, 2],
    'amount': [250, 150, 200, 300, 350]
})



df = pd.merge(left = customers  , right = purchases, how = "inner", on = "customer_id")
df1 = df.groupby('name')[['amount']].sum()
df1
# Out:
#          amount
# name
# Alice       450
# Bob         500
# Charlie     300

# %% [markdown]
# Task2_0530. 학생 성적 데이터프레임과 과목 데이터프레임을 결합하여 각 과목별 평균 성적을 계산하여 출력하세요.

# %%
import pandas as pd

# 학생 성적 데이터프레임 생성
grades = pd.DataFrame({
    'student_id': [1, 2, 3, 4, 1, 2, 3, 4],
    'subject_id': [101, 101, 102, 102, 103, 103, 101, 103],
    'grade': [85, 90, 78, 88, 92, 95, 80, 85]
})

# 과목 데이터프레임 생성
subjects = pd.DataFrame({
    'subject_id': [101, 102, 103],
    'subject_name': ['Math', 'Science', 'History']
})

df = pd.merge(left = grades  , right = subjects, how = "inner", on = "subject_id")
df1= df.groupby('subject_id')[['grade']].mean()
df1
df2 = pd.merge(left = subjects, right = df1, how="inner", on ="subject_id")
df2
# Out:
#    subject_id subject_name      grade
# 0         101         Math  85.000000
# 1         102      Science  83.000000
# 2         103      History  90.666667

# %% [markdown]
# Task3_0530. 고객 데이터프레임에서 age가 30 이상이고 spending이 500 이상인 고객을 찾아 출력하세요

# %%
import pandas as pd

# 예제 데이터프레임 생성
customers = pd.DataFrame({
    'customer_id': [1, 2, 3, 4, 5],
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'age': [25, 35, 30, 40, 28],
    'spending': [300, 600, 500, 700, 400]
})
df = customers[(customers['age']>=30) & (customers['spending']>=500)]
df
# Out:
#    customer_id     name  age  spending
# 1            2      Bob   35       600
# 2            3  Charlie   30       500
# 3            4    David   40       700

# %% [markdown]
# Task4_0530. 학생 성적 데이터프레임에서 math_score가 80 이상 90 이하인 학생을 찾아 출력하세요.

# %%
import pandas as pd

# 예제 데이터프레임 생성
students = pd.DataFrame({
    'student_id': [101, 102, 103, 104, 105],
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'math_score': [75, 85, 88, 92, 78],
    'english_score': [80, 78, 82, 88, 90]
})
students
df=students[(students['math_score']>=80)|(students['math_score']<=90)]
df
# Out:
#    student_id     name  math_score  english_score
# 0         101    Alice          75             80
# 1         102      Bob          85             78
# 2         103  Charlie          88             82
# 3         104    David          92             88
# 4         105      Eve          78             90

# %% [markdown]
# Task5_0530. 주어진 titanic3 데이터셋에서 survived 열을 사용하여 생존자와 비생존자의 수를 계산하여 출력하세요.

# %%
import pandas as pd

# 데이터프레임 읽기
file_path = 'titanic3.csv'
df = pd.read_csv(file_path)
df.head()
df1 = df['survived'].value_counts()
df1
# Out:
# survived
# 0    809
# 1    500
# Name: count, dtype: int64

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %% [markdown]
# Task6_0530. 주어진 titanic3 데이터셋에서 pclass 열을 기준으로 각 객실 등급의 평균 운임(fare)을 계산하여 출력하세요.

# %%
df1= df.groupby('pclass')[['fare']].mean()
df1
# Out:
#              fare
# pclass
# 1       87.508992
# 2       21.179196
# 3       13.302889

# %% [markdown]
# Task7_0530. titanic3 각 변수의 상관계수를 통해 각 변수와 목표 변수(생존 여부) 간의 관계를 파악하세요.

# %%
df1 = df[['age','sibsp','parch','fare','survived']]
print(df1.corr(method='pearson'))
# Out:
#                age     sibsp     parch      fare  survived
# age       1.000000 -0.243699 -0.150917  0.178740 -0.055512
# sibsp    -0.243699  1.000000  0.373587  0.160238 -0.027825
# parch    -0.150917  0.373587  1.000000  0.221539  0.082660
# fare      0.178740  0.160238  0.221539  1.000000  0.244265
# survived -0.055512 -0.027825  0.082660  0.244265  1.000000

# %%
import numpy as np

#문자열 변수를 숫자형으로 변환
df['sex'] = df['sex'].map({'male':0,'female':1})

# 숫자형 변수만 선택
numeric_df = df.select_dtypes(include = np.number)

#상관 계수 계산
correlaction_matrix = numeric_df.corr()

# 생존 여부와 상관계수 정렬
survival_correlaction = correlaction_matrix['survived'].sort_values(ascending=False)
print(correlaction_matrix)
df
# Out:
#             pclass  survived       sex       age     sibsp     parch  \
# pclass    1.000000 -0.312469 -0.124617 -0.408106  0.060832  0.018322
# survived -0.312469  1.000000  0.528693 -0.055512 -0.027825  0.082660
# sex      -0.124617  0.528693  1.000000 -0.063645  0.109609  0.213125
# age      -0.408106 -0.055512 -0.063645  1.000000 -0.243699 -0.150917
# sibsp     0.060832 -0.027825  0.109609 -0.243699  1.000000  0.373587
# parch     0.018322  0.082660  0.213125 -0.150917  0.373587  1.000000
# fare     -0.558629  0.244265  0.185523  0.178740  0.160238  0.221539
# body     -0.034642       NaN  0.015903  0.058809 -0.099961  0.051099
#
#               fare      body
# pclass   -0.558629 -0.034642
# survived  0.244265       NaN
# sex       0.185523  0.015903
# age       0.178740  0.058809
# sibsp     0.160238 -0.099961
# parch     0.221539  0.051099
# fare      1.000000 -0.043110
# body     -0.043110  1.000000
#       pclass  survived                                             name  sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton    1
# 1          1         1                   Allison, Master. Hudson Trevor    0
# 2          1         0                     Allison, Miss. Helen Loraine    1
# 3          1         0             Allison, Mr. Hudson Joshua Creighton    0
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1
# ...      ...       ...                                              ...  ...
# 1304       3         0                             Zabour, Miss. Hileni    1
# 1305       3         0                            Zabour, Miss. Thamine    1
# 1306       3         0                        Zakarian, Mr. Mapriededer    0
# 1307       3         0                              Zakarian, Mr. Ortin    0
# 1308       3         0                               Zimmerman, Mr. Leo    0
#
#         age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0     29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1      0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3     30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4     25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# ...     ...    ...    ...     ...       ...      ...      ...  ...    ...
# 1304  14.50      1      0    2665   14.4542      NaN        C  NaN  328.0
# 1305    NaN      1      0    2665   14.4542      NaN        C  NaN    NaN
# 1306  26.50      0      0    2656    7.2250      NaN        C  NaN  304.0
# 1307  27.00      0      0    2670    7.2250      NaN        C  NaN    NaN
# 1308  29.00      0      0  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                              NaN
# 1305                              NaN
# 1306                              NaN
# 1307                              NaN
# 1308                              NaN
#
# [1309 rows x 14 columns]

# %% [markdown]
# Task8_0530. 승객의 가족 크기(동반한 형제자매/배우자 수와 부모/자녀 수의 합)가 생존에 영향을 미치는지를 탐색하여 결과를 출력하세요.

# %%
df1=df.copy()
df1['동행자 수']= df.apply(lambda x: x['sibsp'] + x['parch'],axis=1)
df2 = df1.sort_values(by='동행자 수' ,ascending=False)
df2[['name','survived','동행자 수']].head(10)

df2.groupby('동행자 수')[['survived']].mean()
# Out:
#        survived
# 동행자 수
# 0      0.302532
# 1      0.536170
# 2      0.566038
# 3      0.697674
# 4      0.272727
# 5      0.200000
# 6      0.250000
# 7      0.000000
# 10     0.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['survived'].plot(kind='hist', bins=20, title='survived')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_1['survived'].plot(kind='line', figsize=(8, 4), title='survived')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
#정답 예시
#가족 크기 계산
df['family_size'] = df['sibsp']+df['parch']

#생존 여부와 가족 크기의 관계 탐색
survival_family_correlation = df[['family_size', 'survived']].corr().iloc[0,1]

survival_family_correlation
# Out:
# 0.02687643412533259

# %%
import matplotlib.pyplot as plt

# 가족 크기별 생존율 계산
family_survival_rate = df.groupby('family_size')['survived'].mean()

# 그래프 그리기
plt.figure(figsize=(10, 6))
family_survival_rate.plot(kind='bar', color='skyblue')
plt.title('Survival Rate by Family Size')
plt.xlabel('Family Size')
plt.ylabel('Survival Rate')
plt.xticks(rotation=0)
plt.grid(axis='y')

plt.show()

# %% [markdown]
# Task9_0530. 객실 등급별 평균 요금(mean_fare_by_pclass)이 생존에 미치는 영향을 분석하기 위해 mean_fare_by_pclass라는 파생 변수를 생성하여 출력하세요.

# %%
df1 = df.groupby('pclass')[['fare']].mean()
df1
# Out:
#              fare
# pclass
# 1       87.508992
# 2       21.179196
# 3       13.302889

# %%
#정답 예시
mean_fare_by_pclass = df.groupby('pclass')['fare'].mean().to_dict()
print(mean_fare_by_pclass,'\n')

#객실 등급별 변수 요금 파생 변수 생성
df['mean_fare_by_pclass'] = df['pclass'].map(mean_fare_by_pclass)
df[['pclass','fare','mean_fare_by_pclass']].head()
# Out:
# {1: 87.50899164086687, 2: 21.179196389891697, 3: 13.302888700564973}
#    pclass      fare  mean_fare_by_pclass
# 0       1  211.3375            87.508992
# 1       1  151.5500            87.508992
# 2       1  151.5500            87.508992
# 3       1  151.5500            87.508992
# 4       1  151.5500            87.508992

# %%
# mean_fare_by_pclass와 생존 여부 간의 상관계수 계산
mean_fare_survival_correlation = df[['mean_fare_by_pclass', 'survived']].corr().iloc[0,1]

mean_fare_survival_correlation
# Out:
# 0.2918753351352463

# %%
 #생존율과 Mean Fare by Pclass 간의 막대그래프 그리기

# 생존율 계산
survival_rate_by_fare = df.groupby('mean_fare_by_pclass')['survived'].mean()

# 그래프 그리기
plt.figure(figsize=(12, 6))
survival_rate_by_fare.plot(kind='bar', color='lightblue')
plt.title('Survival Rate by Mean Fare by Pclass')
plt.xlabel('Mean Fare by Pclass')
plt.ylabel('Survival Rate')
plt.xticks(rotation=45)
plt.grid(axis='y')

plt.show()
