# %% [markdown]
# Task1_0617. 선그래프, 히스토그램, 산점도, 막대그래프 4개의 subplot으로 구성된 2 x 2 그래프를 작성하세요.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame({'A': np.random.randn(1000),
                   'B': np.random.randn(1000),
                   'C': np.random.randn(1000) *100,
                   'D': np.random.randint(1,100,1000)})

fig, axes = plt.subplots(2,2,figsize=(18,15))
df.plot(kind='line',x='A',y='B',ax=axes[0,0])
df.plot(kind='hist',y='C',ax=axes[0,1])
df.plot(kind='scatter',x='A',y='B',ax=axes[1,0])
df.plot(kind='bar',y='D',ax=axes[1,1])
# Out:
# <Axes: >
