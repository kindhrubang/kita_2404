# %% [markdown]
# ##c
#
#
# -csv
# -json
# -excel

# %%
# csv 파일 읽고 저장하기
import numpy as np
import pandas as pd
ar1 = np.arange(10).reshape(2,5)
df = pd.DataFrame(ar1,columns=list('abcde'))
df.to_csv('test.csv')

# %%
# csv 파일 읽고 저장하기
import numpy as np
import pandas as pd
ar1 = np.arange(10).reshape(2,5)
df = pd.DataFrame(ar1,columns=list('abcde'))
df.to_csv('test.csv', index=None)# 이러면 불러올때 index_col=0 안해도 됨

# %%
# !ls
# Out:
# sample_data  test.csv

# %%
df = pd.read_csv('test.csv', index_col=0)
df
# Out:
#    a  b  c  d  e
# 0  0  1  2  3  4
# 1  5  6  7  8  9

# %%
df = pd.read_csv('test.csv')
df
# Out:
#    Unnamed: 0  a  b  c  d  e
# 0           0  0  1  2  3  4
# 1           1  5  6  7  8  9

# %%
df
# Out:
#    a  b  c  d  e
# 0  0  1  2  3  4
# 1  5  6  7  8  9

# %%
df1 = df.copy()

# %%
df1.to_csv('test1.csv')
df1 = pd.read_csv('test1.csv', index_col = 0)
df1
# Out:
#    a  b  c  d  e
# 0  0  1  2  3  4
# 1  5  6  7  8  9

# %%
df1.iloc[0]=2
df1.iloc[1]=3
df1
# Out:
#    a  b  c  d  e
# 0  2  2  2  2  2
# 1  3  3  3  3  3

# %%
# json 파일 읽고 쓰기
df1.to_json('test2.json')
df_j = pd.read_json('test2.json')
df_j
# Out:
#    a  b  c  d  e
# 0  2  2  2  2  2
# 1  3  3  3  3  3

# %%
# 바이너리 파일 읽고 쓰기
df1.to_pickle('test3.pkl')
df1 = pd.read_pickle('test3.pkl')
df1
# Out:
#    a  b  c  d  e
# 0  2  2  2  2  2
# 1  3  3  3  3  3

# %% [markdown]
# Q. 간단한 데이터프레임 작성 후 csv,json,pickle 형태로 저장 후 다시 불러와서 출력하세요

# %%
df = pd.DataFrame(np.random.rand(4,5))
df
# Out:
#           0         1         2         3         4
# 0  0.593982  0.406347  0.551024  0.999909  0.693189
# 1  0.985902  0.164931  0.394681  0.883004  0.540916
# 2  0.255870  0.887578  0.490163  0.001714  0.358535
# 3  0.910740  0.039157  0.008439  0.975304  0.058813

# %%
df.to_csv('크크')

# %%
df.to_json('흐흐')
df.to_pickle('트트')

# %%
df1= pd.read_csv('크크')
df1
# Out:
#    Unnamed: 0         0         1         2         3         4
# 0           0  0.593982  0.406347  0.551024  0.999909  0.693189
# 1           1  0.985902  0.164931  0.394681  0.883004  0.540916
# 2           2  0.255870  0.887578  0.490163  0.001714  0.358535
# 3           3  0.910740  0.039157  0.008439  0.975304  0.058813

# %%
df1= pd.read_json('흐흐')
df1
# Out:
#           0         1         2         3         4
# 0  0.593982  0.406347  0.551024  0.999909  0.693189
# 1  0.985902  0.164931  0.394681  0.883004  0.540916
# 2  0.255870  0.887578  0.490163  0.001714  0.358535
# 3  0.910740  0.039157  0.008439  0.975304  0.058813

# %%
df1= pd.read_pickle('트트')
df1
# Out:
#           0         1         2         3         4
# 0  0.593982  0.406347  0.551024  0.999909  0.693189
# 1  0.985902  0.164931  0.394681  0.883004  0.540916
# 2  0.255870  0.887578  0.490163  0.001714  0.358535
# 3  0.910740  0.039157  0.008439  0.975304  0.058813

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)

# %%
# 엑셀 파일 읽고 쓰기
df = pd.read_excel('auto-mpg.xlsx')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.to_excel('test5.xlsx')
# !ls
# Out:
# 흐흐  크크	     sample_data  test2.json  test5.xlsx
# 트트  auto-mpg.xlsx  test1.csv	  test3.pkl   test.csv

# %%
df = pd.read_excel('test5.xlsx',index_col=0)
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
