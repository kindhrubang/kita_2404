# %%
import pandas as pd
import numpy as np

# %%
galaxy = pd.read_csv('D:\kdt_240424\m3\crawling\Team_search\갤럭시\Galaxy_진짜최종_완전판.csv')
galaxy
# Out:
#        data_pid          location    price                 time  \
# 0     273826430     서울특별시 성북구 동선동   110000  2024-06-24 20:04:57
# 1     242900756      경기도 부천시 원미1동   165000  2024-06-24 19:49:57
# 2     274918206     서울특별시 금천구 가산동   140000  2024-06-24 19:23:57
# 3     271008580     인천광역시 남구 주안1동   110000  2024-06-24 19:23:57
# 4     274903662     서울특별시 금천구 가산동   125000  2024-06-24 18:23:57
# ...         ...               ...      ...                  ...
# 6789  262903675      경기도 양주시 옥정2동  1150000  2024-05-25 20:09:34
# 6790  257516757      전라북도 익산시 오산면  1410000  2024-04-25 20:09:34
# 6791  258048001   경기도 고양시 덕양구 흥도동  1480000  2024-04-25 20:09:34
# 6792  259695644  서울특별시 성동구 왕십리도선동  1450000  2024-04-25 20:09:34
# 6793  258759155   경기도 수원시 권선구 구운동  1400000  2024-04-25 20:09:34
#
#                                        title  month brand   series    model  \
# 0                      갤럭시s10 5g 256 잔상폰 팝니다     64    삼성  갤럭시 S10  regular
# ...

# %%
iphon=pd.read_csv('D:\kdt_240424\m3\crawling\Team_search\아이폰_통합_final3.csv')
iphon
# Out:
#         data_pid                location      price                 time  \
# 0      267940868            경기도 남양주시 오남읍   205000.0  2024-06-24 14:47:56
# 1      273929367            경상남도 김해시 삼안동   200000.0  2024-06-24 12:47:56
# 2      273342608           인천광역시 서구 청라1동   250000.0  2024-06-24 12:47:56
# 3      260249440          인천광역시 남동구 만수2동   230000.0  2024-06-24 11:47:56
# 4      243798033          서울특별시 강남구 삼성2동   210000.0  2024-06-23 21:47:57
# ...          ...                     ...        ...                  ...
# 12173  260671589  충청북도 청주시 서원구 성화.개신.죽림동  1100000.0  2024-04-27 05:12:16
# 12174  260439999            경기도 하남시 신장2동  1100000.0  2024-04-27 05:12:19
# 12175  259355875           경상남도 김해시 장유1동  1200000.0  2024-04-27 05:12:21
# 12176  257219297           서울특별시 서초구 잠원동  1300000.0  2024-03-28 05:12:27
# 12177  240122224          서울특별시 노원구 상계5동  1600000.0  2023-10-30 05:12:29
#
#                             title  month brand  series    model storage
# ...

# %%
df= pd.concat([iphon,galaxy])

# %%
#시리즈내 모델별 가격 분포
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(x='series', y='price', hue='model', data=df)
plt.title('Price Distribution by Model in Series')
plt.xlabel('Series')
plt.ylabel('Price')
plt.show()
# Out:
# d:\kdt_240424\m3\crawling\myenv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\kdt_240424\m3\crawling\myenv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\kdt_240424\m3\crawling\myenv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54256 (\N{HANGUL SYLLABLE PON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\kdt_240424\m3\crawling\myenv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44068 (\N{HANGUL SYLLABLE GAEL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
