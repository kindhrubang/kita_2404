# %% [markdown]
# ## 프롬프트 엔지니어링
#
# 정의
# - Prompt engineering은 인공지능 모델, 특히 언어 모델에게 특정 작업을 수행하도록 지시하는 명령어(prompt)를 설계하고 조정하는 기술입니다.
# - 사용자는 명확하고 구체적인 질문이나 지시를 통해 모델이 원하는 결과를 생성하도록 유도할 수 있습니다. 이 과정은 자연어 처리에서 중요한 역할을 하며, 모델의 출력을 최적화하고 정확도를 높이는 데 기여합니다.
#
# 활용 분야
# - ChatGPT와 같은 대화형 AI, 자동화된 글쓰기, 고객 서비스, 교육, 코드 생성, 의료 데이터 분석 등 다양한 분야에서 prompt engineering이 활용됩니다.
# - 이를 통해 AI가 특정 요구 사항에 맞춘 결과를 생성하도록 하여, 작업 효율성을 높이고 사용자 경험을 향상시킬 수 있습니다.
#
# 사례들은 대규모 언어 모델(LLM)을 활용하는 다양한 방법을 보여줍니다. 각 사례는 특정 작업에 맞게 프롬프트를 설계하여 모델이 어떻게 유용한 결과를 생성하는지 설명합니다.
#
# - 텍스트 생성: 창의적인 글쓰기, 마케팅 카피 작성, 기술 문서 생성 등 다양한 분야에서 사용됩니다. 프롬프트의 구체성과 맥락 설정에 따라 생성되는 텍스트의 품질이 달라집니다.
#
# - 코드 생성 및 보완: 개발자가 원하는 코드 스니펫을 생성하거나 오류를 수정하는 데 도움을 줍니다. 예를 들어, 특정 함수나 알고리즘을 구현할 때 LLM을 활용해 코드를 제안받을 수 있습니다.
#
# - 데이터 분석 및 요약: 대량의 데이터를 요약하거나 분석 결과를 해석하는 데 유용합니다. LLM을 통해 데이터를 자연어로 쉽게 설명할 수 있어, 비전문가도 결과를 이해하기 쉽게 만듭니다.
#
# - 교육 및 학습 지원: 특정 주제에 대한 설명을 제공하거나, 학습 문제를 풀 때 힌트를 제시하는 방식으로 활용됩니다. 이는 교육용 도구나 학습 지원 시스템에서 유용하게 쓰일 수 있습니다.
#
# - 대화형 응용: 고객 서비스, 개인 비서 역할을 하는 챗봇 등에서 LLM이 활용됩니다. 사용자의 질문에 대해 신속하고 정확한 답변을 제공하며, 자연스러운 대화를 통해 사용자 경험을 향상시킵니다.
#
# - 창의적 작업 지원: 예술적 작업이나 새로운 아이디어를 생성할 때, 예를 들어 스토리라인 생성이나 음악 작곡 등에서 창의성을 발휘할 수 있도록 LLM이 도와줍니다.

# %% [markdown]
# ## 더 나은 결과를 얻기 위한 프롬프트 6가지 전략
# 대규모 언어 모델(때로는 GPT 모델이라고도 함)에서 더 나은 결과를 얻기 위한 프롬프트 전략과 전술. 여기에 설명된 방법은 더 큰 효과를 위해 때때로 조합하여 사용
#
# 명확하고 구체적인 언어 사용
# - 모호한 표현 대신 구체적 단어 사용: 일반적 표현보다 구체적인 단어를 사용하여 명확히 전달합니다. 예: "빠르다" 대신 "5분 내에".
# - 명확한 문장 구조 유지: 단문을 사용하여 문장이 복잡하지 않도록 합니다.
#
# 단계별 지침 제공
# - 작업 분할: 작업을 여러 단계로 나누어 각 단계를 명확히 설명합니다.
# - 단계별 결과 명시: 각 단계에서 기대되는 결과를 구체적으로 작성합니다.
#
# 필요한 컨텍스트 제공
# - 관련 배경 정보 포함: 작업을 이해하는 데 필요한 배경 정보를 제공합니다.
# - 구체적 시간/상황 명시: 언제 또는 어떤 상황에서 작업이 수행되는지 명시합니다.
#
# 예시 제공
# - 긍정적/부정적 예시 포함: 올바른 예시와 잘못된 예시를 모두 제공하여 비교할 수 있게 합니다.
# - 다양한 시나리오 제시: 다양한 상황에 대한 예시를 포함합니다.
#
# 부가 정보 제공
# - 추가 리소스 링크 제공: 참고할 수 있는 추가 자료나 링크를 제공합니다.
# - 참조 자료 목록화: 관련 자료들을 목록으로 정리하여 쉽게 접근할 수 있게 합니다.
#
# 피드백 및 조정
# - 피드백 요청: 지침의 명확성을 확인하기 위해 사용자로부터 피드백을 요청합니다.
# - 지침 조정: 받은 피드백을 반영하여 지침을 수정하고 개선합니다.

# %% [markdown]
# **명확하고 구체적인 언어 사용**
#
# 모호한 표현 대신 구체적 단어 사용
# - 모호한 표현: "빠르게 제출하세요."
# - 구체적 표현: "5분 내에 제출하세요."
#
# 모호한 표현인 "빠르게"는 사람마다 다르게 해석될 수 있습니다. 어떤 사람에게는 "빠르게"가 1시간을 의미할 수도 있고, 다른 사람에게는 몇 분을 의미할 수도 있습니다. 반면 "5분 내에"는 정확한 시간을 명시하여 모두가 같은 의미로 이해할 수 있게 합니다. 이를 통해 지침의 명확성이 높아져 오해가 줄어들고, 작업이 더 정확하게 수행될 수 있습니다.
#
# **명확한 문장 구조 유지**
# - 복잡한 문장: "프로젝트 파일을 검토하고, 오류를 수정하며, 다음 회의 전에 팀원들과 공유하세요."
# - 단순한 문장: "프로젝트 파일을 검토하세요. 오류를 수정하세요. 다음 회의 전에 팀원들과 공유하세요."
#
# 복잡한 문장은 여러 작업을 한 문장에 포함하여 읽는 사람이 이해하기 어렵게 만듭니다. 단순한 문장은 각 작업을 별도의 문장으로 분리하여 각 지시사항을 명확하게 전달합니다. 이를 통해 독자는 각 작업의 순서와 중요성을 쉽게 파악할 수 있으며, 오해나 실수를 줄일 수 있습니다.
#
# **작업 분할**
# - 복잡한 작업 지시: "보고서를 작성하고 검토한 후, 이메일로 보내세요."
# - 단계별 작업 지시:<br>
#   - 보고서 작성:
#     - 관련 데이터를 수집하세요.
#     - 수집한 데이터를 분석하여 요약하세요.
#     - 분석 결과를 바탕으로 보고서를 작성하세요.
#   - 보고서 검토:
#     - 작성한 보고서를 읽고 오류를 수정하세요.
#     - 팀원에게 보고서를 공유하고 피드백을 받으세요.
#
#   - 이메일로 전송:
#     - 검토한 보고서를 이메일에 첨부하세요.
#     - 적절한 수신자에게 이메일을 보내세요.
#
# 작업을 여러 단계로 분할하면 각 단계의 구체적인 작업이 명확해집니다. 이를 통해 사용자는 각 단계를 하나씩 완료하면서 전체 작업을 체계적으로 수행할 수 있습니다. 작업 분할은 복잡한 작업을 관리 가능하고 이해하기 쉽게 만듭니다.
#
# **단계별 결과 명시**
# - 작업 지시: 보고서를 작성하고 검토한 후, 이메일로 보내세요.
# - 단계별 결과 명시:
#   - 보고서 작성:
#     - 결과: 초안 보고서 완성. 데이터가 정확히 포함되어 있음.
#   - 보고서 검토:
#     - 결과: 오류가 수정된 보고서. 피드백이 반영됨.
#   - 이메일로 전송:
#     - 결과: 보고서가 이메일에 첨부되어 적절한 수신자에게 전송됨.
#
# 각 단계에서 기대되는 결과를 구체적으로 명시하면 사용자가 작업의 목표를 명확히 이해할 수 있습니다. 이를 통해 단계별로 작업의 완성도를 확인할 수 있고, 최종 결과물이 기대에 부합하는지 확인할 수 있습니다. 단계별 결과 명시는 작업의 명확성과 효율성을 높이는 데 중요한 역할을 합니다.
#
# **관련 배경 정보 포함**
# - 지시사항: "지난 주의 프로젝트 파일을 검토하세요."
# - 관련 배경 정보 포함:
#   - 프로젝트 개요:
#     - 배경 정보: "이 프로젝트는 고객 만족도 향상을 목표로 합니다. 지난 주 회의에서 고객 피드백을 분석하고, 이를 반영한 새로운 전략을 논의했습니다."
#   - 특정 파일 지시:
#     - 배경 정보: "지난 주에 작성된 '고객 피드백 분석 보고서'와 '전략 수정 제안서' 파일을 검토하세요. 이 파일들은 프로젝트 폴더의 '2024년 8월' 섹션에 있습니다."
#   - 검토 목적:
#     - 배경 정보: "이번 검토는 제안된 전략이 효과적인지 평가하고, 추가 개선 사항을 도출하는 것을 목표로 합니다."
#
# 작업을 이해하는 데 필요한 배경 정보를 제공하면 사용자가 작업의 목적과 맥락을 명확히 이해할 수 있습니다. 이로 인해 작업 수행의 정확성과 효율성이 높아집니다. 배경 정보는 작업의 중요성, 관련 문서 위치, 수행해야 할 구체적 내용 등을 포함할 수 있습니다.
#
# **구체적 시간/상황 명시**
# - 모호한 지시사항: "회의 전에 보고서를 작성하세요."
# - 구체적 지시사항:
#   - 시간 명시:
#     - 구체적 표현: "월요일 오전 9시 회의 전에 보고서를 작성하세요."
#     - 상황: "회의는 매주 월요일 오전 9시에 시작됩니다. 이 회의에서 이번 주 목표와 작업 분담이 논의될 예정입니다."
#   - 상황 명시:
#     - 구체적 표현: "월간 실적 검토 회의 전에, 이번 달 매출 보고서를 작성하세요."
#     - 상황: "월간 실적 검토 회의는 매월 마지막 금요일 오후 3시에 열립니다. 이 보고서는 전체 팀의 실적을 평가하는 데 사용됩니다."
#
# 구체적인 시간과 상황을 명시하면 작업의 시기와 맥락을 명확히 할 수 있습니다. 이는 사용자가 언제 작업을 완료해야 하는지 정확히 이해하게 하여, 일정 준수와 작업의 적시 수행을 도와줍니다. 또한, 작업의 중요성과 맥락을 이해함으로써, 더 나은 준비와 수행이 가능해집니다.
#
# **긍정적/부정적 예시 포함**
# - 지시사항: "이메일을 작성하세요."
# - 긍정적 예시:
#   - 제목: "회의 일정 확인 요청"
#   - 내용: "안녕하세요, 김 팀장님. 이번 주 금요일 오후 2시에 예정된 회의 일정을 확인하고자 합니다. 참석 가능하신지 알려주시면 감사하겠습니다. 감사합니다. 홍길동 드림."
# - 부정적 예시:
#   - 제목: "회의"
#   - 내용: "안녕하세요, 회의가 이번 주 금요일에 있을 것 같습니다. 참석할 수 있는지 알려주세요. 홍길동."
#
# 긍정적 예시와 부정적 예시를 제공하면 사용자는 무엇이 올바르고 무엇이 잘못된지 명확히 이해할 수 있습니다. 긍정적 예시는 최상의 결과를 보여주어 기대하는 바를 명확히 전달하며, 부정적 예시는 피해야 할 실수를 구체적으로 보여줍니다. 이를 통해 사용자는 지침을 더 잘 따르고, 결과물의 품질을 높일 수 있습니다.
#
# **다양한 시나리오 제시**
# - 지시사항: "보고서를 작성하세요."
# - 다양한 시나리오:
#   - 주간 보고서 작성:
#     - 상황: 매주 금요일마다 주간 업무 요약 보고서를 작성합니다.
#     - 포함 내용: 주요 성과, 문제점, 다음 주 계획.
#     - 긍정적 예시: "이번 주 주요 성과로는 판매 목표 120% 달성이 있습니다. - 문제점으로는 재고 부족이 있었으며, 이를 해결하기 위해 다음 주에는 재고 보충 계획을 세웠습니다."
#     - 부정적 예시: "이번 주에 여러 가지 일이 있었고, 다음 주에도 할 일이 많습니다."
#   - 프로젝트 보고서 작성:
#     - 상황: 프로젝트 마감 시 프로젝트 진행 상황과 결과를 요약한 보고서를 작성합니다.
#     - 포함 내용: 프로젝트 목표, 진행 상황, 최종 결과, 배운 점.
#     - 긍정적 예시: "프로젝트 목표는 고객 만족도 향상이었고, 진행 상황은 계획대로 진행되었습니다. 최종 결과로 고객 만족도가 20% 향상되었습니다. 배운 점은 초기 계획의 중요성입니다."
#     - 부정적 예시: "프로젝트가 끝났고, 결과가 나왔습니다."
#   - 연구 보고서 작성:
#     - 상황: 연구 프로젝트의 결과를 발표하기 위한 보고서를 작성합니다.
#     - 포함 내용: 연구 목적, 방법, 결과, 결론.
#     - 긍정적 예시: "연구 목적은 새로운 항생제의 효과를 검증하는 것이었습니다. 실험 방법은 무작위 대조 실험이었고, 결과는 긍정적이었습니다. 결론은 새로운 항생제가 효과적이라는 것입니다."
#     - 부정적 예시: "연구를 했고, 결과가 좋았습니다."
#
# 다양한 시나리오를 제시하면 사용자는 각 상황에 맞게 작업을 어떻게 수행해야 하는지 명확히 이해할 수 있습니다. 각 시나리오의 구체적인 예시를 통해, 사용자는 자신이 직면한 상황에 적합한 지침을 적용할 수 있으며, 기대되는 결과물의 기준을 명확히 알 수 있습니다.
#
# **추가 리소스 링크 제공 및 참조 자료 목록화**
# - 지시사항: "보고서를 작성하기 위한 참고 자료를 확인하세요."
# - 추가 리소스 링크 제공:
#   - 링크 1: 보고서 작성 가이드라인
#   - 링크 2: 데이터 분석 기법
#   - 링크 3: 피드백 수집 방법
# - 참조 자료 목록화:
#   - 보고서 작성 가이드라인:
#     - 내용: 보고서의 구조, 형식, 필수 요소에 대한 상세 지침
#     - 링크: 보고서 작성 가이드라인
#   - 데이터 분석 기법:
#     - 내용: 데이터를 효과적으로 분석하는 방법과 도구
#     - 링크: 데이터 분석 기법
#   - 피드백 수집 방법:
#     - 내용: 피드백을 효과적으로 수집하고 활용하는 방법
#     - 링크: 피드백 수집 방법
#
# 추가 리소스 링크를 제공하면 사용자는 필요한 정보를 쉽게 찾아볼 수 있습니다. 참조 자료를 목록화하면 관련 자료를 체계적으로 정리하여 사용자가 필요할 때 빠르게 접근할 수 있게 도와줍니다. 이는 작업의 정확성과 효율성을 높이는 데 매우 유용합니다.
#
# **피드백 요청**
# - 지시사항: "보고서를 작성한 후, 제출하세요."
# - 피드백 요청 추가:
#   - 초안 제출:
#     - 지시사항: "보고서 초안을 작성한 후, 팀원들에게 공유하세요."
#     - 피드백 요청: "초안에 대한 피드백을 받으세요. 피드백을 바탕으로 수정 사항을 반영하세요."
#   - 최종본 제출:
#     - 지시사항: "피드백을 반영한 최종 보고서를 작성한 후, 제출하세요."
#     - 피드백 요청: "제출 전, 팀원 또는 관리자에게 최종 확인을 요청하세요. 보고서의 명확성과 완성도를 높이기 위해 피드백을 활용하세요."
#
# 피드백 요청을 통해 지침의 명확성을 확인하고 개선할 수 있습니다. 사용자로부터 피드백을 받으면, 지침이 제대로 이해되고 있는지 확인할 수 있으며, 필요한 경우 수정하여 더 명확하고 효과적인 지침을 제공할 수 있습니다. 이를 통해 작업의 품질과 정확성을 높일 수 있습니다.
#
# **지침 조정**
# - 초기 지침:
# "프로젝트 계획서를 작성하세요."
# - 피드백:
#   - "계획서에 포함해야 할 세부 항목이 명확하지 않습니다."
#   - "완료 기한이 명시되지 않아 혼란스럽습니다."
# - 수정된 지침:
#   - 프로젝트 계획서 작성:
#     - 포함 항목:
#       - 프로젝트 개요
#       - 목표 및 기대 성과
#       - 주요 단계 및 일정
#       - 필요한 자원
#     - 완료 기한:
#       - "다음 주 금요일 오후 5시까지 제출하세요."
#
# 피드백을 반영하여 지침을 수정하면, 지침의 명확성과 효과성이 개선됩니다. 사용자가 작업을 더 정확하고 효율적으로 수행할 수 있도록 도와줍니다. 피드백을 통해 지침의 문제점을 파악하고, 구체적이고 명확한 지침으로 수정하는 과정이 중요합니다.

# %%
# %pip install -q openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.4 MB/s eta 0:00:00

# %%
from openai import OpenAI
client = OpenAI(api_key="")

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {'role': "system", 'content': "당신은 AI 모델 개발자이다."},
        {'role': "user", 'content': "LLM에 대해 설명해줘."},

    ]
)
# print(completion.choices[0].message.content)
print(completion)
# Out:
# ChatCompletion(id='chatcmpl-9vF1wl4EN3UULZkhEfiqO7V7IWNfl', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='LLM(대형 언어 모델, Large Language Model)은 자연어 처리(NLP) 분야에서 사용되는 인공지능 모델의 일종으로, 대량의 텍스트 데이터를 학습하여 언어를 이해하고 생성할 수 있는 능력을 갖추고 있습니다. 이러한 모델은 일반적으로 다음과 같은 특징을 가지고 있습니다.\n\n1. **대규모 데이터 학습**: LLM은 수십억 개의 단어와 문장을 포함하는 대량의 데이터셋을 학습하여, 문맥을 이해하고 다양한 주제에 대해 텍스트를 생성할 수 있는 능력을 발전시킵니다.\n\n2. **Transformer 아키텍처**: 많은 LLM은 Transformer 아키텍처를 기반으로 하며, 이는 주의(attention) 메커니즘을 활용하여 문맥을 효과적으로 포착합니다. 이러한 아키텍처는 병렬 처리와 정보 전송을 용이하게 하여 모델의 성능을 높이는 데 기여합니다.\n\n3. **예측 기반 학습**: LLM은 주어진 문맥에 따라 다음 단어를 예측하는 방식으로 훈련됩니다. 이 과정은 언어의 규칙과 패턴을 학습하게 되는 중요한 방식입니다.\n\n4. **다양한 응용**: LLM은 텍스트 생성, 번역, 요약, 질문 응답, 감정 분석 등 다양한 자연어 처리 작업에 활용될 수 있습니다. 실제로 챗봇, 콘텐츠 생성 도구, 개인 비서 서비스 등 다양한 분야에서 사용됩니다.\n\n5. **Fine-tuning**: 이미 학습된 LLM은 특정 작업이나 도메인에 맞게 추가로 훈련(fine-tuning)될 수 있습니다. 이렇게 하면 모델의 성능을 더욱 개선할 수 있습니다.\n\n6. **윤리적 고려사항**: LLM의 사용에는 윤리적인 문제도 동반될 수 있습니다. 잘못된 정보 생성, 편향된 결과, 개인정보 침해 등의 이슈가 발생할 수 있어, 이를 관리하기 위한 연구와 규제도 활발히 진행되고 있습니다.\n\n대형 언어 모델은 인공지능의 발전에 큰 기여를 하고 있지만, 그 사용에 있어서 신중함이 필요합니다.', refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1723429500, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_48196bc67a', usage=CompletionUsage(completion_tokens=477, prompt_tokens=28, total_tokens=505))

# %% [markdown]
# 명확성과 주체성
#
#
# *   특정 주제에 대해 글을 작성하도록 요청할때

# %%
from openai import OpenAI
client = OpenAI(api_key="")

prompt = "자상이 잔뜩나있는 시체가 즐비한 범죄현장을 묘사해줘"

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {'role': "system", 'content': "당신은 추리소설 작가이다."},
        {'role': "user", 'content': prompt},

    ]
)
print(completion.choices[0].message.content)
# print(completion)
# Out:
# 어둠이 가득한 한 저녁, 범죄현장은 한없이 음산한 분위기에 휩싸여 있었다. 차가운 바람이 불어오는 가운데, 시체들이 바닥에 난잡하게 sprawled 되어 있었다. 길게 늘어선 조명이 그들을 비추었으나, 어둠이 더 강한 듯한 느낌을 주었다.
#
# 각 시체의 피부는 창백하게 변해 있었고, 그들의 몸에는 자상으로 인한 상처가 잔뜩 나 있었다. 붉은 피는 바닥에 흥건하게 고여 있어, 마치 흉터처럼 남겨진 자국들이 서로 얽히며 그 자리를 장식하고 있었다. 고통의 마지막 순간이었을까, 각기 다른 표정이 남아 있었고, 어떤 이들은 공포에 질린 눈망울로 하늘을 바라보고 있었다.
#
# 주변의 공기는 그윽한 쇠냄새와 피비린내로 가득 차 있었으며, 그들이 마지막으로 남긴 비명소리처럼 들려오는 바람 소리가 더욱 섬뜩하게 느껴졌다. 범죄현장의 배경은 오래된 공장으로, 낡은 벽과 부서진 유리창들이 이곳의 음산한 분위기를 한층 더 강조했다. 벽면을 따라 흐르는 곰팡이와 시체의 모습은 마치 좀비 영화의 한 장면을 연상케 했다.
#
# 탐정은 이러한 장면을 마주하며 쌀쌀한 기운이 등줄기를 타고 흘러내리는 것을 느꼈다. 이곳에서 벌어진 끔찍한 사건의 진상을 밝혀내기 위해 그는 깊은 심호흡을 하며 발을 내디뎠다. 그가 들고 있는 플래시라이트의 빛이 시체의 자상과 그 주변의 흔적들을 더 또렷이 비추며, 진실의 조각들이 서서히 드러나기 시작했다.

# %% [markdown]
# 맥락 제공
#
#
#
# *   특정 사건에 대한 설명을 요청할때

# %%
from openai import OpenAI
client = OpenAI(api_key=)

prompt =(
    "다음 맥락을 고려하여 대답해 주세요: '그녀와 나는 5년간의 연애끝에 결혼에 성공하였고 드디어 신혼여행을 오게된 첫날밤이다.'"
    "이때 일어날 일들을 소설처럼 작성해주세요"
)

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {'role': "system", 'content': "당신은 추리,살인,심리적 공포를 잘 묘사하는 작가이다."},
        {'role': "user", 'content': prompt},

    ]
)
print(completion.choices[0].message.content)
# print(completion)
# Out:
# 그녀와 나는 5년간의 연애 끝에 결혼에 성공하였고 드디어 신혼여행을 오게된 첫날밤이다. 이른 저녁, 해가 지고 난 뒤의 조용한 호텔 방은 부드러운 야경의 빛으로 물들어 있었다. 커플 소파에 나란히 앉아, 첫 잔의 샴페인을 부딪히며 고운 미소를 지었다. 행복한 순간이지만, 마음 한켠에선 묘한 긴장감이 감돌았다.
#
# 그녀는 내게 눈을 맞추며 말을 건넸다. "내가 이렇게 결혼할 줄은 몰랐어." 그녀의 목소리에는 설렘과 함께 약간의 불안이 섞여 있었다. 나는 그녀의 손을 꼭 잡고 "이제는 우리만의 시간이야, 모든 것을 잊고 즐기자."라고 대답했다.
#
# 그러나 그 순간, 호텔 방에선 이상한 소리가 들려오기 시작했다. 처음에는 바람에 흔들리는 커튼 소리처럼 들렸지만, 점점 더 반복적으로 뚝뚝 쿵쿵 하는 소리가 귀를 자극했다. "무슨 소리야?" 그녀의 얼굴은 점점 하얗게 변해갔다. 나는 "아마 뭔가 설치고 있는 것 같아."라고 대충 넘겼지만, 마음 속에서는 불안감이 커져갔다.
#
# 그 소리와 함께 슬프고 애달픈 멜로디가 흐르기 시작했다. 나는 음악의 출처를 찾아 방 안을 이리저리 돌아다녔지만, 그 매력적인 악곡이 어디서 나는지 알 수 없었다. 마치 저 멀리 있는 음악이 방 안으로 스며드는 듯한 기분이었다. 그녀는 갑자기 조용해졌다. "이상해... 뭔가 불길한 느낌이 들어." 그녀는 옷자락을 움켜잡고 있었다.
#
# 어둠이 내려앉은 방, 그녀의 불안한 눈빛이 나를 사로잡았다. 난 무의식적으로 다가가 그녀의 얼굴을 두 손으로 감싸주고 "내가 있어, 괜찮아."라고 속삭였다. 하지만 그 순간, 방 한쪽에서 시선이 느껴졌다. 그녀의 뒤에 어두운 그림자가 스쳐 지나갔다. 나의 심장이 멈춘 듯했다.
#
# 나는 즉시 그녀를 뒤로 밀어내며 양팔을 벌렸다. "누가 있어?" 집착에 찬 목소리가 들렸다. 내 귀에 고요한 침묵 대신, 차가운 대화가 담긴 듯, 감정이吞였다. "이럴 리가 없어…" 그녀는 경악한 말로 부정하고, 내 쪽으로 더 가까이 다가왔다.
#
# 그 순간, 방의 모든 것이 정지한 듯 느껴졌다. 차가운 바람이 방 안으로 피어오르듯 스산한 냉기가 흐르는 것 같았다. 나는 그녀를 싸안으며 조심스럽게 "우리는 안전해, 아무것도 없다고."라고 말했지만, 그 말은 점점 더 불안한 선율처럼 울려 퍼졌다.
#
# 그녀의 눈빛이 내 마음을 쪼그라뜨리며 한 번 더 묻고 있었다. "정말 괜찮은 거지?" 대답을 하려는 찰나, 다시 한 번 그 그림자가 나타났다. 스치듯 방의 분위기를 캄캄하게 바꿔놓았다.
#
# 그림자는 우리를 벗어나지 않으리라는 듯, 서서히 다가오고 있었다. 한순간의 정적 후에, 온 몸을 감싸는 공포가 밀려왔고, 나는 분명 무언가가 우리를 잡으러 오는 것이 느껴졌다. 하지만 결코 의식을 잃지 않겠다는 결심으로 그녀를 더욱 쩔어 매지며 서서히 더듬거렸다.
#
# "우리가 연애할 때, 항상 힘든 일들이 있었잖아." 그녀가 소리쳤다. "그때 항상 넌 나를 지켜줬어. 나를 믿어줘!" 무너지는 마음으로 간신히 대답했다. "우리는 함께야."
#
# 그림자는 점점 더 가까워졌고, 나와 그녀는 더 이상 어디로 숨을 수 없는 지독한 공포 속에 빠져들고 있었다. 하지만 나는 알고 있었다. 아무리 어둡고 고통스러운 순간이라도, 우리는 결코 이길 수 없는 싸움을 하지 않았다. 무슨 일이 일어나든지 함께할 거라는 다짐이 그들에게도 들릴 듯, 내 심장은 더욱 더 맥을 빠르게 뛰었다.
#
# 첫날밤의 불안한 정적 속으로 우리가 나아가게 될 것이다. 의지와 사랑이 강해질 때, 무엇보다 강한 빛이 되어줄 것이다. 하지만 그런 맹세와 함께, 불길한 그림자는 우리를 향해 웃고 있었을지도 모른다.

# %% [markdown]
# 반복과 테스트
#
# *   여러 프롬프트를 테스트하여 최적의 결과 도출

# %%
prompts =[
    "정기적인 운동의 건강상의 이점은 무엇인가요?",
    "주기적인 칼로리 소모에 이점은 무엇인가요?",
    "정기적인 신체적 활동이 건강에 어떤 영향을 미치나요?",
    "가학적으로 스스로의 몸을 한계까지 몰아붙이는 운동이라는것의 이점이 있을까요?"
]
from openai import OpenAI
client = OpenAI(api_key='')
for prompt in prompts:
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {'role': "system", 'content': "당신은 한평생 운동을 공부하고 실행해온 핼스트레이너이자 운동전문가이다."},
            {'role': "user", 'content': prompt},

        ]
    )
    print(f"프롬프트: {prompt}")
    print(completion.choices[0].message.content)
    print('=======================================================================')
# print(completion)
# Out:
# 프롬프트: 정기적인 운동의 건강상의 이점은 무엇인가요?
# 정기적인 운동은 여러 가지 건강상의 이점을 제공합니다. 주요 이점은 다음과 같습니다:
#
# 1. **심혈관 건강 증진**: 규칙적인 운동은 심장과 폐의 기능을 향상시켜 심혈관 질환의 위험을 감소시킵니다.
#
# 2. **체중 관리**: 운동은 칼로리를 소모하여 체중을 관리하고 비만을 예방하는 데 도움을 줍니다.
#
# 3. **근육 및 뼈 강화**: 저항 운동은 근육을 강화하고 뼈 밀도를 증가시켜 골다공증과 같은 뼈 관련 질환을 예방합니다.
#
# 4. **정신 건강 개선**: 운동은 스트레스를 줄이고 기분을 좋게 하는 호르몬인 엔돌핀의 분비를 증가시킵니다. 이는 우울증과 불안 증상을 완화하는 데 도움을 줍니다.
#
# 5. **면역 체계 강화**: 규칙적인 신체 활동은 면역 체계를 강화하여 감염에 대한 저항력을 높이는 데 기여합니다.
#
# 6. **수면 질 향상**: 운동은 수면 패턴을 개선하고 깊은 수면을 촉진합니다.
#
# 7. **혈당 조절**: 운동은 인슐린 감수성을 향상시키고 혈당 수치를 조절하여 제2형 당뇨병 예방에 기여합니다.
#
# 8. **인지 기능 개선**: 운동은 뇌의 혈류를 증가시키고, 이는 집중력 및 기억력 향상에 도움이 됩니다.
#
# 9. **사회적 상호작용**: 운동을 통해 사회적 활동에 참여할 수 있으며, 이는 인간 관계를 강화하고 고립감을 줄이는 데 기여합니다.
#
# 10. **전반적인 삶의 질 향상**: 정기적인 운동은 에너지를 증진시키고 전반적인 행복감을 높이며, 삶의 질을 향상시킵니다.
#
# 정기적인 운동은 이러한 이점뿐만 아니라, 개인의 건강 목표에 따라 다양한 긍정적인 효과를 가져다줄 수 있습니다.
# =======================================================================
# 프롬프트: 주기적인 칼로리 소모에 이점은 무엇인가요?
# 주기적인 칼로리 소모는 신체와 정신 모두에 여러 가지 이점을 제공합니다. 다음은 그 몇 가지 주요 이점입니다:
#
# 1. **체중 관리**: 주기적으로 칼로리를 소모함으로써 체중을 효율적으로 관리할 수 있습니다. 이를 통해 체중 증가를 예방하고, 필요시 체중 감량을 도울 수 있습니다.
#
# 2. **대사 증가**: 규칙적인 운동과 칼로리 소모는 기초 대사율을 높이는 데 도움을 줄 수 있습니다. 이는 더 많은 칼로리를 소모하게 해 주며, 장기적으로 체중 관리에 긍정적인 영향을 미칠 수 있습니다.
#
# 3. **에너지 수준 향상**: 운동을 통해 칼로리를 소모하면 신체의 에너지원이 개선되고, 일상적인 활동에서의 피로감이 줄어듭니다. 또한, 심혈관 건강이 개선되면서 더 많은 에너지를 느낄 수 있습니다.
#
# 4. **정신 건강 증진**: 운동은 스트레스 해소, 불안 감소 및 우울증 증상 개선에 도움이 됩니다. 주기적으로 칼로리를 소모하면 기분을 좋게 만드는 호르몬인 엔돌핀이 분비되어 정신적 웰빙에도 긍정적인 영향을 미칩니다.
#
# 5. **근력 및 유연성 향상**: 규칙적인 운동은 근육을 강화하고 유연성을 증가시키는 효과가 있습니다. 이는 부상 예방 및 일상 생활의 활동성을 높이는 데 기여합니다.
#
# 6. **건강한 생활습관 형성**: 지속적인 칼로리 소모는 균형 잡힌 식단과 함께 건강한 생활습관을 형성하는 데 도움이 됩니다. 운동이 일상의 일부가 됨으로써 더 나은 건강 유지에 기여할 수 있습니다.
#
# 7. **심장 건강 개선**: 주기적인 유산소 운동은 심혈관 건강을 증진시키며, 이는 고혈압과 심장병 예방에 도움이 됩니다.
#
# 이와 같은 이점들은 칼로리 소모를 통해 신체뿐 아니라 정신적으로도 긍정적인 영향을 미치며, 장기적으로 건강한 삶을 유지하는 데 중요한 요소가 됩니다.
# =======================================================================
# 프롬프트: 정기적인 신체적 활동이 건강에 어떤 영향을 미치나요?
# 정기적인 신체적 활동은 건강에 여러 가지 긍정적인 영향을 미칩니다. 주요 효과는 다음과 같습니다:
#
# 1. **심혈관 건강 개선**: 규칙적인 운동은 심장과 혈관의 기능을 향상시켜 고혈압과 심장병의 위험을 낮춥니다.
#
# 2. **체중 관리**: 신체 활동은 칼로리를 소모하게 하여 체중 조절에 도움을 줍니다.
#
# 3. **근육 및 골격 강화**: 다양한 운동은 근육을 강화하고 뼈 밀도를 높여 골다공증을 예방하는 데 도움이 됩니다.
#
# 4. **정신 건강 증진**: 운동은 스트레스를 줄이고 우울증 및 불안 증상을 완화하는 데 효과적입니다. 엔돌핀과 같은 긍정적인 화학물질을 방출하여 기분을 개선합니다.
#
# 5. **면역 체계 지원**: 규칙적인 신체 활동은 면역력을 강화하여 여러 질병에 대한 저항력을 높일 수 있습니다.
#
# 6. **수면 질 향상**: 운동은 수면의 질을 개선하고 불면증 증상을 줄이는 데 도움을 줄 수 있습니다.
#
# 7. **대사 기능 개선**: 신체 활동은 인슐린 감수성을 높이고 당뇨병 예방에 기여합니다.
#
# 8. **인지 기능 향상**: 운동은 뇌 기능을 향상시키고 기억력, 주의력 및 사고 능력을 증진시키는 데 도움이 될 수 있습니다.
#
# 9. **생활의 질 향상**: 운동은 에너지를 증진시키고 전반적인 삶의 질을 개선하는 데 기여합니다.
#
# 결론적으로, 정기적으로 신체적 활동을 하는 것은 전반적인 건강과 웰빙을 유지하는 데 매우 중요합니다. 최소 주 150분의 중등도 강도의 유산소 운동과 근력 운동을 포함하는 것이 권장됩니다.
# =======================================================================
# 프롬프트: 가학적으로 스스로의 몸을 한계까지 몰아붙이는 운동이라는것의 이점이 있을까요?
# 가학적으로 스스로의 몸을 한계까지 몰아붙이는 운동은 극단적인 훈련 방식이며, 일반적으로 권장되지 않습니다. 하지만 이 방식이 가진 몇 가지 이점과 단점에 대해 살펴볼 수 있습니다.
#
# ### 이점
# 1. **정신적 강인함**: 자신의 한계를 넘어서는 경험은 정신력을 강화시킬 수 있습니다. 극복감을 느끼며 자신감이 상승할 수 있습니다.
# 2. **체력 향상**: 고강도 훈련은 체력과 지구력을 향상시킬 수 있으며, 단기간에 신체 능력의 발전을 이끌어낼 수 있습니다.
# 3. **운동 수행 능력 향상**: 특정 스포츠나 운동에서 뛰어난 퍼포먼스를 요구할 경우, 극단적인 훈련이 필요할 수 있습니다.
#
# ### 단점
# 1. **부상 위험**: 과도한 훈련은 부상의 위험을 높이며, 장기적으로는 신체에 심각한 손상을 초래할 수 있습니다.
# 2. **회복 부족**: 충분한 회복 없이 고강도 훈련을 반복하면 피로가 누적되어 오히려 성능 저하를 가져올 수 있습니다.
# 3. **정신적 스트레스**: 지나친 압박감은 스트레스와 불안으로 이어질 수 있으며, 운동에 대한 흥미를 잃게 만들 수 있습니다.
#
# 따라서, 목표가 무엇이든지 간에 극단적인 훈련 방식을 피하고, 균형 잡힌 운동 계획과 적절한 회복이 중요합니다. 건강하고 지속 가능한 운동 습관을 유지하는 것이 장기적으로 더 많은 이점을 가져올 것입니다.
# =======================================================================
