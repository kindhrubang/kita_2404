# %%
import pandas as pd
import numpy as np

# %%
df10 = pd.read_csv('갤럭시 s10_0624_2025.csv')
df10['series'] =np.nan
df10
# Out:
#        data_pid                                        href  \
# 0     274935090  https://m.bunjang.co.kr/products/274935090
# 1     274931154  https://m.bunjang.co.kr/products/274931154
# 2     273826430  https://m.bunjang.co.kr/products/273826430
# 3     274928565  https://m.bunjang.co.kr/products/274928565
# 4     274916457  https://m.bunjang.co.kr/products/274916457
# ...         ...                                         ...
# 2995  262636279  https://m.bunjang.co.kr/products/262636279
# 2996  261781058  https://m.bunjang.co.kr/products/261781058
# 2997  261616020  https://m.bunjang.co.kr/products/261616020
# 2998  261950131  https://m.bunjang.co.kr/products/261950131
# 2999  263372010  https://m.bunjang.co.kr/products/263372010
#
#                                               image_url        location  \
# 0     https://media.bunjang.co.kr/product/274935090_...     경기도 김포시 풍무동
# 1     https://media.bunjang.co.kr/product/274931154_...         지역정보 없음
# ...

# %%
df10['title']=df10['title'].str.lower()

idx = df10[df10['title'].str.contains('s10')].index
for i in idx:
    df10.at[i, 'series'] = '갤럭시 S10'
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2512\3357316541.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '갤럭시 S10' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df10.at[i, 'series'] = '갤럭시 S10'

# %%
df10=df10.dropna()
df10.to_csv('10_G.csv')
df10
# Out:
#        data_pid                                        href  \
# 0     274935090  https://m.bunjang.co.kr/products/274935090
# 1     274931154  https://m.bunjang.co.kr/products/274931154
# 2     273826430  https://m.bunjang.co.kr/products/273826430
# 3     274928565  https://m.bunjang.co.kr/products/274928565
# 4     274916457  https://m.bunjang.co.kr/products/274916457
# ...         ...                                         ...
# 2995  262636279  https://m.bunjang.co.kr/products/262636279
# 2996  261781058  https://m.bunjang.co.kr/products/261781058
# 2997  261616020  https://m.bunjang.co.kr/products/261616020
# 2998  261950131  https://m.bunjang.co.kr/products/261950131
# 2999  263372010  https://m.bunjang.co.kr/products/263372010
#
#                                               image_url        location  \
# 0     https://media.bunjang.co.kr/product/274935090_...     경기도 김포시 풍무동
# 1     https://media.bunjang.co.kr/product/274931154_...         지역정보 없음
# ...

# %%
df20 = pd.read_csv('갤럭시 s20_0624_2019.csv')
df20['series'] = np.nan
df20
# Out:
#        data_pid                                        href  \
# 0     274930572  https://m.bunjang.co.kr/products/274930572
# 1     274928855  https://m.bunjang.co.kr/products/274928855
# 2     274926434  https://m.bunjang.co.kr/products/274926434
# 3     274921819  https://m.bunjang.co.kr/products/274921819
# 4     274923099  https://m.bunjang.co.kr/products/274923099
# ...         ...                                         ...
# 4995  260213289  https://m.bunjang.co.kr/products/260213289
# 4996  259756467  https://m.bunjang.co.kr/products/259756467
# 4997  256517273  https://m.bunjang.co.kr/products/256517273
# 4998  259988205  https://m.bunjang.co.kr/products/259988205
# 4999  259783494  https://m.bunjang.co.kr/products/259783494
#
#                                               image_url          location  \
# 0     https://media.bunjang.co.kr/product/274930572_...           지역정보 없음
# 1     https://media.bunjang.co.kr/product/274928855_...           지역정보 없음
# ...

# %%
df20['title']=df20['title'].str.lower()

idx = df20[df20['title'].str.contains('s20')].index
for i in idx:
    df20.at[i, 'series'] = '갤럭시 S20'

idx = df20[df20['title'].str.contains('s 20')].index
for i in idx:
    df20.at[i, 'series'] = '갤럭시 S20'

df20=df20.dropna()
df20.to_csv('20_G.csv')
df20
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2512\1593264965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df20['title']=df20['title'].str.lower()
#        data_pid                                        href  \
# 0     274930572  https://m.bunjang.co.kr/products/274930572
# 1     274928855  https://m.bunjang.co.kr/products/274928855
# 2     274926434  https://m.bunjang.co.kr/products/274926434
# 3     274921819  https://m.bunjang.co.kr/products/274921819
# 4     274923099  https://m.bunjang.co.kr/products/274923099
# ...         ...                                         ...
# 4995  260213289  https://m.bunjang.co.kr/products/260213289
# 4996  259756467  https://m.bunjang.co.kr/products/259756467
# ...

# %%
df21 = pd.read_csv('갤럭시 s21_0624_2016.csv')
df21['series'] = np.nan
df21
# Out:
#        data_pid                                        href  \
# 0     274933014  https://m.bunjang.co.kr/products/274933014
# 1     274932828  https://m.bunjang.co.kr/products/274932828
# 2     274874425  https://m.bunjang.co.kr/products/274874425
# 3     274563764  https://m.bunjang.co.kr/products/274563764
# 4     269053639  https://m.bunjang.co.kr/products/269053639
# ...         ...                                         ...
# 4995  235588471  https://m.bunjang.co.kr/products/235588471
# 4996  235586610  https://m.bunjang.co.kr/products/235586610
# 4997  235468565  https://m.bunjang.co.kr/products/235468565
# 4998  235186168  https://m.bunjang.co.kr/products/235186168
# 4999  235582872  https://m.bunjang.co.kr/products/235582872
#
#                                               image_url         location  \
# 0     https://media.bunjang.co.kr/product/274933014_...          지역정보 없음
# 1     https://media.bunjang.co.kr/product/274932828_...          지역정보 없음
# ...

# %%
df21['title']=df21['title'].str.lower()

idx = df21[df21['title'].str.contains('s21')].index
for i in idx:
    df21.at[i, 'series'] = '갤럭시 S21'

idx = df21[df21['title'].str.contains('s 21')].index
for i in idx:
    df21.at[i, 'series'] = '갤럭시 S21'

df21=df21.dropna()
df21.to_csv('21_G.csv')
df21
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2512\2421299249.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '갤럭시 S21' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df21.at[i, 'series'] = '갤럭시 S21'
#        data_pid                                        href  \
# 0     274933014  https://m.bunjang.co.kr/products/274933014
# 1     274932828  https://m.bunjang.co.kr/products/274932828
# 2     274874425  https://m.bunjang.co.kr/products/274874425
# 3     274563764  https://m.bunjang.co.kr/products/274563764
# 4     269053639  https://m.bunjang.co.kr/products/269053639
# ...         ...                                         ...
# 4995  235588471  https://m.bunjang.co.kr/products/235588471
# 4996  235586610  https://m.bunjang.co.kr/products/235586610
# 4997  235468565  https://m.bunjang.co.kr/products/235468565
# ...

# %%
df22 = pd.read_csv('갤럭시 s22_0624_2014.csv')
df22['series'] = np.nan
df22
# Out:
#        data_pid                                        href  \
# 0     274932673  https://m.bunjang.co.kr/products/274932673
# 1     274932097  https://m.bunjang.co.kr/products/274932097
# 2     274931246  https://m.bunjang.co.kr/products/274931246
# 3     253939487  https://m.bunjang.co.kr/products/253939487
# 4     273512828  https://m.bunjang.co.kr/products/273512828
# ...         ...                                         ...
# 4995  267738840  https://m.bunjang.co.kr/products/267738840
# 4996  264266322  https://m.bunjang.co.kr/products/264266322
# 4997  268742463  https://m.bunjang.co.kr/products/268742463
# 4998  263931202  https://m.bunjang.co.kr/products/263931202
# 4999  266872294  https://m.bunjang.co.kr/products/266872294
#
#                                               image_url          location  \
# 0     https://media.bunjang.co.kr/product/274932673_...  경기도 수원시 권선구 세류2동
# 1     https://media.bunjang.co.kr/product/274932097_...           지역정보 없음
# ...

# %%
df22['title']=df22['title'].str.lower()

idx = df22[df22['title'].str.contains('s22')].index
for i in idx:
    df22.at[i, 'series'] = '갤럭시 S22'

idx = df22[df22['title'].str.contains('s 22')].index
for i in idx:
    df22.at[i, 'series'] = '갤럭시 S22'

df22=df22.dropna()
df22.to_csv('22_G.csv')
df22
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2512\111096536.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '갤럭시 S22' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df22.at[i, 'series'] = '갤럭시 S22'
#        data_pid                                        href  \
# 0     274932673  https://m.bunjang.co.kr/products/274932673
# 1     274932097  https://m.bunjang.co.kr/products/274932097
# 2     274931246  https://m.bunjang.co.kr/products/274931246
# 3     253939487  https://m.bunjang.co.kr/products/253939487
# 4     273512828  https://m.bunjang.co.kr/products/273512828
# ...         ...                                         ...
# 4995  267738840  https://m.bunjang.co.kr/products/267738840
# 4996  264266322  https://m.bunjang.co.kr/products/264266322
# 4997  268742463  https://m.bunjang.co.kr/products/268742463
# ...

# %%
df22[df22['title']=='[수원영통] 갤럭시 s20플러스 5g 256gb 블루 - 34757']
# Out:
# Empty DataFrame
# Columns: [data_pid, href, image_url, location, price, time, title, series]
# Index: []

# %%
df23 = pd.read_csv('갤럭시 s23_0624_2013.csv')
df23['series'] = '갤럭시 S23'
df23
# Out:
#        data_pid                                        href  \
# 0     254215410  https://m.bunjang.co.kr/products/254215410
# 1     251469069  https://m.bunjang.co.kr/products/251469069
# 2     274930343  https://m.bunjang.co.kr/products/274930343
# 3     274931008  https://m.bunjang.co.kr/products/274931008
# 4     274737803  https://m.bunjang.co.kr/products/274737803
# ...         ...                                         ...
# 4995  263931104  https://m.bunjang.co.kr/products/263931104
# 4996  263931005  https://m.bunjang.co.kr/products/263931005
# 4997  263265221  https://m.bunjang.co.kr/products/263265221
# 4998  263891531  https://m.bunjang.co.kr/products/263891531
# 4999  268244661  https://m.bunjang.co.kr/products/268244661
#
#                                               image_url          location  \
# 0     https://media.bunjang.co.kr/product/254215410_...           지역정보 없음
# 1     https://media.bunjang.co.kr/product/251469069_...           지역정보 없음
# ...

# %%
df23['title']=df23['title'].str.lower()

idx = df23[df23['title'].str.contains('s23')].index
for i in idx:
    df23.at[i, 'series'] = '갤럭시 S23'

idx = df23[df23['title'].str.contains('s 23')].index
for i in idx:
    df23.at[i, 'series'] = '갤럭시 S23'

df23=df23.dropna()
df23.to_csv('23_G.csv')
df23
# Out:
#        data_pid                                        href  \
# 2     274930343  https://m.bunjang.co.kr/products/274930343
# 3     274931008  https://m.bunjang.co.kr/products/274931008
# 4     274737803  https://m.bunjang.co.kr/products/274737803
# 6     267676771  https://m.bunjang.co.kr/products/267676771
# 7     272080541  https://m.bunjang.co.kr/products/272080541
# ...         ...                                         ...
# 4995  263931104  https://m.bunjang.co.kr/products/263931104
# 4996  263931005  https://m.bunjang.co.kr/products/263931005
# 4997  263265221  https://m.bunjang.co.kr/products/263265221
# 4998  263891531  https://m.bunjang.co.kr/products/263891531
# 4999  268244661  https://m.bunjang.co.kr/products/268244661
#
#                                               image_url          location  \
# 2     https://media.bunjang.co.kr/product/274930343_...           지역정보 없음
# 3     https://media.bunjang.co.kr/product/274931008_...       경기도 김포시 풍무동
# ...

# %%
df24 = pd.read_csv('갤럭시 s24_0624_2009.csv')
df24['series'] = np.nan
df24
# Out:
#        data_pid                                        href  \
# 0     239792802  https://m.bunjang.co.kr/products/239792802
# 1     265669322  https://m.bunjang.co.kr/products/265669322
# 2     258889037  https://m.bunjang.co.kr/products/258889037
# 3     238002490  https://m.bunjang.co.kr/products/238002490
# 4     274917688  https://m.bunjang.co.kr/products/274917688
# ...         ...                                         ...
# 4995  259115345  https://m.bunjang.co.kr/products/259115345
# 4996  259177361  https://m.bunjang.co.kr/products/259177361
# 4997  259185249  https://m.bunjang.co.kr/products/259185249
# 4998  255326076  https://m.bunjang.co.kr/products/255326076
# 4999  259000290  https://m.bunjang.co.kr/products/259000290
#
#                                               image_url          location  \
# 0     https://media.bunjang.co.kr/product/239792802_...           지역정보 없음
# 1     https://media.bunjang.co.kr/product/265669322_...     서울특별시 용산구 용문동
# ...

# %%
df24['title']=df24['title'].str.lower()

idx = df24[df24['title'].str.contains('s24')].index
for i in idx:
    df24.at[i, 'series'] = '갤럭시 S24'

idx = df24[df24['title'].str.contains('s 24')].index
for i in idx:
    df24.at[i, 'series'] = '갤럭시 S24'

df24=df24.dropna()
df24.to_csv('24_G.csv')
df24
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2512\3151896736.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '갤럭시 S24' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df24.at[i, 'series'] = '갤럭시 S24'
#        data_pid                                        href  \
# 2     258889037  https://m.bunjang.co.kr/products/258889037
# 3     238002490  https://m.bunjang.co.kr/products/238002490
# 4     274917688  https://m.bunjang.co.kr/products/274917688
# 6     274917943  https://m.bunjang.co.kr/products/274917943
# 7     249947163  https://m.bunjang.co.kr/products/249947163
# ...         ...                                         ...
# 4181  259695644  https://m.bunjang.co.kr/products/259695644
# 4182  260325231  https://m.bunjang.co.kr/products/260325231
# 4200  258759155  https://m.bunjang.co.kr/products/258759155
# ...

# %%
df = pd.concat([ df10,df20,df21,df22,df23,df24], axis = 0)
df
# Out:
#        data_pid                                        href  \
# 0     274935090  https://m.bunjang.co.kr/products/274935090
# 1     274931154  https://m.bunjang.co.kr/products/274931154
# 2     273826430  https://m.bunjang.co.kr/products/273826430
# 3     274928565  https://m.bunjang.co.kr/products/274928565
# 4     274916457  https://m.bunjang.co.kr/products/274916457
# ...         ...                                         ...
# 4181  259695644  https://m.bunjang.co.kr/products/259695644
# 4182  260325231  https://m.bunjang.co.kr/products/260325231
# 4200  258759155  https://m.bunjang.co.kr/products/258759155
# 4614  262960261  https://m.bunjang.co.kr/products/262960261
# 4964  255031955  https://m.bunjang.co.kr/products/255031955
#
#                                               image_url          location  \
# 0     https://media.bunjang.co.kr/product/274935090_...       경기도 김포시 풍무동
# 1     https://media.bunjang.co.kr/product/274931154_...           지역정보 없음
# ...

# %%
df['title']=df['title'].str.lower()
df
# Out:
#        data_pid                                        href  \
# 0     274935090  https://m.bunjang.co.kr/products/274935090
# 1     274931154  https://m.bunjang.co.kr/products/274931154
# 2     273826430  https://m.bunjang.co.kr/products/273826430
# 3     274928565  https://m.bunjang.co.kr/products/274928565
# 4     274916457  https://m.bunjang.co.kr/products/274916457
# ...         ...                                         ...
# 4995  259115345  https://m.bunjang.co.kr/products/259115345
# 4996  259177361  https://m.bunjang.co.kr/products/259177361
# 4997  259185249  https://m.bunjang.co.kr/products/259185249
# 4998  255326076  https://m.bunjang.co.kr/products/255326076
# 4999  259000290  https://m.bunjang.co.kr/products/259000290
#
#                                               image_url          location  \
# 0     https://media.bunjang.co.kr/product/274935090_...       경기도 김포시 풍무동
# 1     https://media.bunjang.co.kr/product/274931154_...           지역정보 없음
# ...

# %%
idx = df[df['title'].str.contains("'s10'")].index
for i in idx:
    df.at[i, 'series'] = '갤럭시 S10'

idx = df[df['title'].str.contains("'s20'")].index
for i in idx:
    df.at[i, 'series'] = '갤럭시 S20'

idx = df[df['title'].str.contains('"s21"')].index
for i in idx:
    df.at[i, 'series'] = '갤럭시 S21'

idx = df[df['title'].str.contains('"s22"')].index
for i in idx:
    df.at[i, 'series'] = '갤럭시 S22'

idx = df[df['title'].str.contains('"s23"')].index
for i in idx:
    df.at[i, 'series'] = '갤럭시 S23'

idx = df[df['title'].str.contains('"s24"')].index
for i in idx:
    df.at[i, 'series'] = '갤럭시 S24'

# %%
df
# Out:
#        data_pid                                        href  \
# 0     274935090  https://m.bunjang.co.kr/products/274935090
# 1     274931154  https://m.bunjang.co.kr/products/274931154
# 2     273826430  https://m.bunjang.co.kr/products/273826430
# 3     274928565  https://m.bunjang.co.kr/products/274928565
# 4     274916457  https://m.bunjang.co.kr/products/274916457
# ...         ...                                         ...
# 4995  259115345  https://m.bunjang.co.kr/products/259115345
# 4996  259177361  https://m.bunjang.co.kr/products/259177361
# 4997  259185249  https://m.bunjang.co.kr/products/259185249
# 4998  255326076  https://m.bunjang.co.kr/products/255326076
# 4999  259000290  https://m.bunjang.co.kr/products/259000290
#
#                                               image_url          location  \
# 0     https://media.bunjang.co.kr/product/274935090_...       경기도 김포시 풍무동
# 1     https://media.bunjang.co.kr/product/274931154_...           지역정보 없음
# ...

# %%
idx = df[df['title'].str.contains('s20')].index
for i in idx:
    df.at[i, 'series'] = '갤럭시 S20'

# %%
idx = df[df['title'].str.contains('s20')].index
idx
# Out:
# Index([ 935, 1605, 1616, 2014, 2369, 2388, 2451, 2501, 2503, 2584,
#        ...
#        4932, 4933, 4937, 4947, 4952, 4967, 4978, 4979, 4993, 4999],
#       dtype='int64', length=5755)

# %%
# ,아이폰 12 미니 64GB,아이폰 12 미니 128GB,아이폰 12 미니 256GB,아이폰 12 64GB,아이폰 12 128GB,아이폰 12 256GB,아이폰 12 PRO 128GB,아이폰 12 PRO 256GB,아이폰 12 PRO 512GB,아이폰 12 PRO MAX 128GB,아이폰 12 PRO MAX 256GB,아이폰 12 PRO MAX 512GB

# %%
#default
df['brand'] = '애플'

# %%
#default
df['seires']='아이폰 13'

# %%
#default
df['model'] = 'regular'

# %%
df['title']=df['title'].str.lower()
df['coment']=df['coment'].str.lower()

# %%
df
# Out:
#                            title  \
# 0                      아이폰13 128
# 1       아이폰13프로 시에라블루 256g 배터리91
# 2                   아이폰 13 128기가
# 3           아이폰13 128기가 미드나잇 팔아여
# 4      아이폰 13프로맥스 셔터음 무음 자급제 팝니다
# ...                          ...
# 2563                    아이폰 13미니
# 2564  아이폰13미니 256 미드나이트 (카메라 무음)
# 2565   iphone 13-128gb = 520.000
# 2566       아이폰13프로 시에라블루 128g s급
# 2567       아이폰13프로 시에라블루 128g s급
#
#                                                  coment  \
# 0     아이폰 13  128기가 화이트색상입니다 선택약정 가능하며 쓰시던유심 그대로 끼워서...
# 1     아이폰13프로 256g 정상해지 팝니다  충전기제외 풀박스  수리이력 정식 및 사설...
# 2     아이폰 13 128기가 미드나잇 색상 입니다 배터리효율85퍼센트 짱짱해요 선택약정가...
# 3     <통신사 3사 전부 사용가능> 유심기변용!!! 정상 공기계 에요  100% 실사!!...
# 4     사진처럼 상태 좋습니다  128기가 배터리86프로  수리이력없고 액정기스없고 깨끗합...
# ...                                                 ...
# 2563  아이폰13미니 미드나잇 블랙256기가 기스없는 a급 입니다. 박스,충전기, 사진에 ...
# 2564  미국 la 애플매장에서 구매한 자급제폰으로  카메라 촬영시 소리 안납니다   배터리...
# ...

# %%
df['storage']=np.nan

# %%
# 64GB검출
idx = df[df['title'].str.contains('64')].index
for i in idx:
    df.at[i, 'storage'] = '64'
idx = df[df['coment'].str.contains('64')].index
for i in idx:
    df.at[i, 'storage'] = '64'
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11172\3175069772.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '64' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[i, 'storage'] = '64'

# %%
# 128GB검출
idx = df[df['title'].str.contains('128')].index
for i in idx:
    df.at[i, 'storage'] = '128'
idx = df[df['coment'].str.contains('128')].index
for i in idx:
    df.at[i, 'storage'] = '128'

# %%
# 256GB검출
idx = df[df['title'].str.contains('256')].index
for i in idx:
    df.at[i, 'storage'] = '256'
idx = df[df['coment'].str.contains('256')].index
for i in idx:
    df.at[i, 'storage'] = '256'

# %%
# 512GB검출
idx = df[df['title'].str.contains('512')].index
for i in idx:
    df.at[i, 'storage'] = '512'
idx = df[df['coment'].str.contains('512')].index
for i in idx:
    df.at[i, 'storage'] = '512'

# %%
# 1TB검출
idx = df[df['title'].str.contains('테라')].index
for i in idx:
    df.at[i, 'storage'] = '1TB'
idx = df[df['coment'].str.contains('테라')].index
for i in idx:
    df.at[i, 'storage'] = '1TB'
idx = df[df['title'].str.contains('1tb')].index
for i in idx:
    df.at[i, 'storage'] = '1TB'
idx = df[df['coment'].str.contains('1tb')].index
for i in idx:
    df.at[i, 'storage'] = '1TB'

# %%
df
# Out:
#                            title  \
# 0                      아이폰13 128
# 1       아이폰13프로 시에라블루 256g 배터리91
# 2                   아이폰 13 128기가
# 3           아이폰13 128기가 미드나잇 팔아여
# 4      아이폰 13프로맥스 셔터음 무음 자급제 팝니다
# ...                          ...
# 2563                    아이폰 13미니
# 2564  아이폰13미니 256 미드나이트 (카메라 무음)
# 2565   iphone 13-128gb = 520.000
# 2566       아이폰13프로 시에라블루 128g s급
# 2567       아이폰13프로 시에라블루 128g s급
#
#                                                  coment  \
# 0     아이폰 13  128기가 화이트색상입니다 선택약정 가능하며 쓰시던유심 그대로 끼워서...
# 1     아이폰13프로 256g 정상해지 팝니다  충전기제외 풀박스  수리이력 정식 및 사설...
# 2     아이폰 13 128기가 미드나잇 색상 입니다 배터리효율85퍼센트 짱짱해요 선택약정가...
# 3     <통신사 3사 전부 사용가능> 유심기변용!!! 정상 공기계 에요  100% 실사!!...
# 4     사진처럼 상태 좋습니다  128기가 배터리86프로  수리이력없고 액정기스없고 깨끗합...
# ...                                                 ...
# 2563  아이폰13미니 미드나잇 블랙256기가 기스없는 a급 입니다. 박스,충전기, 사진에 ...
# 2564  미국 la 애플매장에서 구매한 자급제폰으로  카메라 촬영시 소리 안납니다   배터리...
# ...

# %%
df['data_pid']=np.nan

# %%
df['time']=np.nan

# %%
df['month']=np.nan

# %%
df.isnull().sum()
# Out:
# title          0
# coment         0
# region         0
# price          0
# brand          0
# seires         0
# model          0
# storage      222
# data_pid    2568
# time        2568
# month       2568
# dtype: int64

# %%
#모델명 추출 시작
df['title']=df['title'].str.lower()
df['coment']=df['coment'].str.lower()

# %%
# mini 검출
idx = df[df['title'].str.contains('mini')].index
for i in idx:
    df.at[i, 'model'] = 'mini'
idx = df[df['coment'].str.contains('mini')].index
for i in idx:
    df.at[i, 'model'] = 'mini'

idx = df[df['title'].str.contains('미니')].index
for i in idx:
    df.at[i, 'model'] = 'mini'
idx = df[df['coment'].str.contains('미니')].index
for i in idx:
    df.at[i, 'model'] = 'mini'

# %%
# pro 검출
idx = df[df['title'].str.contains('pro')].index
for i in idx:
    df.at[i, 'model'] = 'pro'
idx = df[df['coment'].str.contains('pro')].index
for i in idx:
    df.at[i, 'model'] = 'pro'

idx = df[df['title'].str.contains('프로')].index
for i in idx:
    df.at[i, 'model'] = 'pro'
idx = df[df['coment'].str.contains('프로')].index
for i in idx:
    df.at[i, 'model'] = 'pro'

# %%
# pro max검출
idx = df[df['title'].str.contains('맥스')].index
for i in idx:
    df.at[i, 'model'] = 'pro max'
idx = df[df['coment'].str.contains('맥스')].index
for i in idx:
    df.at[i, 'model'] = 'pro max'

idx = df[df['title'].str.contains('max')].index
for i in idx:
    df.at[i, 'model'] = 'pro max'
idx = df[df['coment'].str.contains('max')].index
for i in idx:
    df.at[i, 'model'] = 'pro max'

# %%
df.rename(columns = {'region':'location'}, inplace=True)

# %%
df.rename(columns = {'seires':'series'}, inplace=True)

# %%
df = df[['data_pid','location','price','time','title','month','brand','series','model','storage','coment']]

# %%
df
# Out:
#       data_pid                     location   price  time  \
# 0          NaN          서울 노원구 상계6.7동        440000   NaN
# 1          NaN           서울 금천구 독산제1동        720000   NaN
# 2          NaN          서울 노원구 상계6.7동        480000   NaN
# 3          NaN            경기도 김포시 사우동        470000   NaN
# 4          NaN            경기도 파주시 탄현면        700000   NaN
# ...        ...                          ...     ...   ...
# 2563       NaN            경기도 광주시 회덕동        450000   NaN
# 2564       NaN            인천 미추홀구 도화동        500000   NaN
# 2565       NaN            경기도 시흥시 정왕동        520000   NaN
# 2566       NaN            경기도 광주시 송정동        650000   NaN
# 2567       NaN            경기도 광주시 송정동        650000   NaN
#
#                            title  month brand  series    model storage  \
# 0                      아이폰13 128    NaN    애플  아이폰 13  regular     128
# 1       아이폰13프로 시에라블루 256g 배터리91    NaN    애플  아이폰 13      pro     256
# ...

# %%
df.to_csv('아이폰13.csv',index=False, encoding="utf-8-sig")
